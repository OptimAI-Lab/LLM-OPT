# %% [markdown]
# # LLM Training as Large-scale Optimization
#
# So far we have already discussed stochastic optimization and the basic SGD scheme (see also [add ref here])
#
# ```{math}
# :label: eq-SGD-again
# \theta^{t+1}\leftarrow \theta^{t} - \eta_t\nabla F(x^t, \xi_t)
# ```

# %% [markdown]
# multi line equation is also possible
#
# ```{math}
# :label: eq-gradient
# \nabla f(x) &= \frac{\partial f}{\partial x} \\
# a+b &= c
# ```
#
# ```{math}
# :label: eq-temp1
# \begin{align}
# a &= b+c \tag{a}\\
# a + b &= c \tag{b}
# \end{align}
# ```
